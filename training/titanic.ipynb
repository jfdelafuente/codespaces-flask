# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import pickle
import json
# Out:
# /home/jfdelafuente/.local/lib/python3.6/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
train_df = pd.read_csv("train.csv")
train_df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 186          187         1       3
# 333          334         0       3
# 336          337         0       1
# 140          141         0       3
# 730          731         1       1
# 588          589         0       3
# 493          494         0       1
# 358          359         1       3
# 472          473         1       2
# 869          870         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 186  O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  female   NaN      1
# 333                  Vander Planke, Mr. Leo Edmondus    male  16.0      2
# 336                        Pears, Mr. Thomas Clinton    male  29.0      1
# 140                    Boulos, Mrs. Joseph (Sultana)  female   NaN      0
# 730                    Allen, Miss. Elisabeth Walton  female  29.0      0
# 588                            Gilinski, Mr. Eliezer    male  22.0      0
# 493                          Artagaveytia, Mr. Ramon    male  71.0      0
# 358                             McGovern, Miss. Mary  female   NaN      0
# 472          West, Mrs. Edwy Arthur (Ada Mary Worth)  female  33.0      1
# 869                  Johnson, Master. Harold Theodor    male   4.0      1
#
#      Parch      Ticket      Fare Cabin Embarked
# 186      0      370365   15.5000   NaN        Q
# 333      0      345764   18.0000   NaN        S
# 336      0      113776   66.6000    C2        S
# 140      2        2678   15.2458   NaN        C
# 730      0       24160  211.3375    B5        S
# 588      0       14973    8.0500   NaN        S
# 493      0    PC 17609   49.5042   NaN        C
# 358      0      330931    7.8792   NaN        Q
# 472      2  C.A. 34651   27.7500   NaN        S
# 869      1      347742   11.1333   NaN        S

# %%
train_df.iloc[313]
# Out:
# PassengerId                       314
# Survived                            0
# Pclass                              3
# Name           Hendekovic, Mr. Ignjac
# Sex                              male
# Age                                28
# SibSp                               0
# Parch                               0
# Ticket                         349243
# Fare                           7.8958
# Cabin                             NaN
# Embarked                            S
# Name: 313, dtype: object

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df = train_df.drop(['Ticket', 'Cabin'], axis=1)
train_df = train_df.drop(['Name', 'PassengerId'], axis=1)

# %%
X_train = train_df.drop('Survived', axis=1)
y_train = train_df['Survived']

# %%
X_train['Sex'].replace(['male', 'female'], [1, 0], inplace=True)
X_train['Embarked'].replace(['S', 'C', 'Q'], [1, 2, 3], inplace=True)

# %%
X_train.tail()
# Out:
#      Pclass  Sex   Age  SibSp  Parch   Fare  Embarked
# 886       2    1  27.0      0      0  13.00       1.0
# 887       1    0  19.0      0      0  30.00       1.0
# 888       3    0   NaN      1      2  23.45       1.0
# 889       1    1  26.0      0      0  30.00       2.0
# 890       3    1  32.0      0      0   7.75       3.0

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-55e337027e4e> in <module>
#       1 clf = RandomForestClassifier()
# ----> 2 clf.fit(X_train.values, y_train)
#       3 # y_pred_train = clf.predict(X_train.values)
#       4 # y_pred = clf.predict(X_test.values)
#       5 # y_acc = accuracy_score(y_test, y_pred)
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     303             )
#     304         X, y = self._validate_data(X, y, multi_output=True,
# --> 305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#     307             sample_weight = _check_sample_weight(sample_weight, X)
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     876                     ensure_min_samples=ensure_min_samples,
#     877                     ensure_min_features=ensure_min_features,
# --> 878                     estimator=estimator)
#     879     if multi_output:
#     880         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     719         if force_all_finite:
#     720             _assert_all_finite(array,
# --> 721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#     723     if ensure_min_samples > 0:
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     104                     msg_err.format
#     105                     (type_err,
# --> 106                      msg_dtype if msg_dtype is not None else X.dtype)
#     107             )
#     108     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
print(y_acc_train)
y_acc_train = accuracy_score(y_train, y_pred_train)

# %%
import pickle
pickle.dump(clf, open('model.pkl', 'wb'))

# %%
model = pickle.load(open('titanic.pkl', 'rb'))

# %%
print(model.predict([[1 2 35 0 2 144.5 1]]))
